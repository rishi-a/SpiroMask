# %%
import numpy as np
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib
import matplotlib.pyplot as plt
import latexify as lt
#LOSO Validation
loo = LeaveOneOut()
n95_mse = []
cloth_mse = []
n95_pe = []
cloth_pe = []

# %%
import pandas as pd
n95 = pd.read_csv("n95Data-rPFT_cleaned.csv").dropna()
n95.head()
# Out:
#    Unnamed: 0                     Filename       rPEF  tPEF     rFEV1  tFEV1  \
# 0           0           005_FVC_N95_1.json   5.550747  4.06  1.350065   2.04
# 1           1           006_FVC_N95_1.json   6.138897  5.57  1.318559   2.77
# 2           2   Anubhav_FVC_N95Mask_2.json  14.353518  6.05  1.636142   3.33
# 3           3       Raviraj_FVC_N95_2.json   9.243270  7.68  1.575493   2.88
# 4           4  Rishiraj_FVC_N95Mask_1.json  14.675015  7.53  1.493551   2.96
#
#        rFVC  tFVC
# 0  2.043578  3.94
# 1  2.019852  3.02
# 2  1.802957  4.33
# 3  1.885437  3.30
# 4  1.919364  3.39

# %% [markdown]
# N95 Mask Only

# %%
#FEV1
X = np.array([[i] for i in n95['rFEV1']])
y=  np.array([i for i in n95['tFEV1']])
loo.get_n_splits(X)
print("Running Regression on FEV1")
mse=0
pe=0
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted FEV1= ", reg.predict(X_test))
    print("True FEV1 = ", y_test)
    mse = mse+mean_squared_error(reg.predict(X_test), y_test)
    pe= pe+np.abs((y_test-reg.predict(X_test))/y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("Percentage Error", np.abs((y_test-reg.predict(X_test))/y_test))
    print("\n")
mse = mse/loo.get_n_splits(X)
pe=pe/loo.get_n_splits(X)
n95_mse.append(mse)
n95_pe.append(pe[0])


#FVC
X = np.array([[i] for i in n95['rFVC']])
y=  np.array([i for i in n95['tFVC']])
loo.get_n_splits(X)
print("Running Regression on FVC")
mse=0
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted FVC= ", reg.predict(X_test))
    print("True FVC = ", y_test)
    mse = mse+mean_squared_error(reg.predict(X_test), y_test)
    pe= pe+np.abs((y_test-reg.predict(X_test))/y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("Percentage Error", np.abs((y_test-reg.predict(X_test))/y_test))
    print("\n")
mse = mse/loo.get_n_splits(X)
pe=pe/loo.get_n_splits(X)
n95_mse.append(mse)
n95_pe.append(pe[0])


#PEF 1 1 2
X = np.array([[i] for i in n95['rPEF']])
y=  np.array([i for i in n95['tPEF']])
loo.get_n_splits(X)
print("Running Regression on PEF")
mse=0
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted PEF= ", reg.predict(X_test))
    print("True PEF = ", y_test)
    mse = mse+mean_squared_error(reg.predict(X_test), y_test)
    pe= pe+np.abs((y_test-reg.predict(X_test))/y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("\n")
mse = mse/loo.get_n_splits(X)
pe=pe/loo.get_n_splits(X)
n95_mse.append(mse)
n95_pe.append(pe[0])
# Out:
# Running Regression on FEV1
# TRAIN: [1 2 3 4 5] TEST: [0]
# Predicted FEV1=  [2.73815336]
# True FEV1 =  [2.04]
# MSE =  0.48741811940001617
# Percentage Error [0.34223204]
#
#
# TRAIN: [0 2 3 4 5] TEST: [1]
# Predicted FEV1=  [1.93369999]
# True FEV1 =  [2.77]
# MSE =  0.6993977092624992
# Percentage Error [0.30191336]
#
#
# TRAIN: [0 1 3 4 5] TEST: [2]
# Predicted FEV1=  [3.38269897]
# True FEV1 =  [3.33]
# MSE =  0.0027771819456574192
# Percentage Error [0.01582552]
#
#
# TRAIN: [0 1 2 4 5] TEST: [3]
# Predicted FEV1=  [3.2556476]
# True FEV1 =  [2.88]
# MSE =  0.14111112053220276
# Percentage Error [0.13043319]
#
#
# TRAIN: [0 1 2 3 5] TEST: [4]
# Predicted FEV1=  [2.90321508]
# True FEV1 =  [2.96]
# MSE =  0.0032245276968608013
# Percentage Error [0.0191841]
#
#
# TRAIN: [0 1 2 3 4] TEST: [5]
# Predicted FEV1=  [3.20935757]
# True FEV1 =  [3.65]
# MSE =  0.19416574856410368
# Percentage Error [0.12072395]
#
#
# Running Regression on FVC
# TRAIN: [1 2 3 4 5] TEST: [0]
# Predicted FVC=  [2.70421364]
# True FVC =  [3.94]
# MSE =  1.5271679345900515
# Percentage Error [0.31365136]
#
#
# TRAIN: [0 2 3 4 5] TEST: [1]
# Predicted FVC=  [3.6375994]
# True FVC =  [3.02]
# MSE =  0.3814290135977915
# Percentage Error [0.20450311]
#
#
# TRAIN: [0 1 3 4 5] TEST: [2]
# Predicted FVC=  [3.82065865]
# True FVC =  [4.33]
# MSE =  0.25942861171558174
# Percentage Error [0.1176308]
#
#
# TRAIN: [0 1 2 4 5] TEST: [3]
# Predicted FVC=  [3.92498077]
# True FVC =  [3.3]
# MSE =  0.3906009624525113
# Percentage Error [0.18938811]
#
#
# TRAIN: [0 1 2 3 5] TEST: [4]
# Predicted FVC=  [3.76517524]
# True FVC =  [3.39]
# MSE =  0.1407564607901589
# Percentage Error [0.11067116]
#
#
# TRAIN: [0 1 2 3 4] TEST: [5]
# Predicted FVC=  [3.80571151]
# True FVC =  [4.24]
# MSE =  0.18860649588360048
# Percentage Error [0.10242653]
#
#
# Running Regression on PEF
# TRAIN: [1 2 3 4 5] TEST: [0]
# Predicted PEF=  [6.60280994]
# True PEF =  [4.06]
# MSE =  6.4658823726695385
#
#
# TRAIN: [0 2 3 4 5] TEST: [1]
# Predicted PEF=  [5.717924]
# True PEF =  [5.57]
# MSE =  0.021881510100774517
#
#
# TRAIN: [0 1 3 4 5] TEST: [2]
# Predicted PEF=  [8.33645622]
# True PEF =  [6.05]
# MSE =  5.227882037244292
#
#
# TRAIN: [0 1 2 4 5] TEST: [3]
# Predicted PEF=  [6.02150023]
# True PEF =  [7.68]
# MSE =  2.7506214770270274
#
#
# TRAIN: [0 1 2 3 5] TEST: [4]
# Predicted PEF=  [7.34583275]
# True PEF =  [7.53]
# MSE =  0.03391757414106308
#
#
# TRAIN: [0 1 2 3 4] TEST: [5]
# Predicted PEF=  [6.07802981]
# True PEF =  [7.79]
# MSE =  2.930841924529401

# %%
pe[0]
# Out:
# 0.15282700752348272

# %% [markdown]
# Cloth Mask

# %%
cloth = pd.read_csv("clothData-rPFT_cleaned.csv").dropna()
cloth.head()
# Out:
#    Unnamed: 0                  Filename       rPEF  tPEF     rFEV1  tFEV1  \
# 0           0      005_FVC_Cloth_1.json   4.744028  4.06  1.238331   2.04
# 1           1      006_FVC_Cloth_2.json   5.946209  5.57  1.360659   2.77
# 2           2      008_FVC_Cloth_1.json  11.221120  7.23  1.624566   2.98
# 3           3      009_FVC_Cloth_2.json   5.705103  6.57  1.310286   3.61
# 4           4  Raviraj_FVC_Cloth_1.json  11.461954  7.68  1.515144   2.88
#
#        rFVC  tFVC
# 0  2.099512  3.94
# 1  1.970481  3.02
# 2  1.822619  3.11
# 3  1.980106  4.09
# 4  1.872934  3.30

# %%
#FEV1
X = np.array([[i] for i in cloth['rFEV1']])
y=  np.array([i for i in cloth['tFEV1']])
loo.get_n_splits(X)
print("Running Regression on FEV1")
mse=0
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted FEV1= ", reg.predict(X_test))
    print("True FEV1 = ", y_test)
    mse = mse+mean_squared_error(reg.predict(X_test), y_test)
    pe= pe+np.abs((y_test-reg.predict(X_test))/y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("\n")
mse = mse/loo.get_n_splits(X)
pe=pe/loo.get_n_splits(X)
cloth_mse.append(mse)
cloth_pe.append(pe[0])


#FVC
X = np.array([[i] for i in cloth['rFVC']])
y=  np.array([i for i in cloth['tFVC']])
loo.get_n_splits(X)
print("Running Regression on FVC")
mse=0
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted FVC= ", reg.predict(X_test))
    print("True FVC = ", y_test)
    mse = mse+mean_squared_error(reg.predict(X_test), y_test)
    pe= pe+np.abs((y_test-reg.predict(X_test))/y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("\n")
mse = mse/loo.get_n_splits(X)
pe=pe/loo.get_n_splits(X)
cloth_mse.append(mse)
cloth_pe.append(pe[0])


#PEF 
X = np.array([[i] for i in cloth['rFVC']])
y=  np.array([i for i in cloth['tFVC']])
loo.get_n_splits(X)
print("Running Regression on PEF")
mse=0
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted PEF= ", reg.predict(X_test))
    print("True PEF = ", y_test)
    mse = mse+mean_squared_error(reg.predict(X_test), y_test)
    pe= pe+np.abs((y_test-reg.predict(X_test))/y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("\n")
mse = mse/loo.get_n_splits(X)
pe=pe/loo.get_n_splits(X)
cloth_mse.append(mse)
cloth_pe.append(pe[0])
# Out:
# Running Regression on FEV1
# TRAIN: [1 2 3 4 5 6] TEST: [0]
# Predicted FEV1=  [3.19390246]
# True FEV1 =  [2.04]
# MSE =  1.3314908912906573
#
#
# TRAIN: [0 2 3 4 5 6] TEST: [1]
# Predicted FEV1=  [2.89047617]
# True FEV1 =  [2.77]
# MSE =  0.014514506638571716
#
#
# TRAIN: [0 1 3 4 5 6] TEST: [2]
# Predicted FEV1=  [3.59268097]
# True FEV1 =  [2.98]
# MSE =  0.375377969178978
#
#
# TRAIN: [0 1 2 4 5 6] TEST: [3]
# Predicted FEV1=  [2.48471845]
# True FEV1 =  [3.61]
# MSE =  1.2662585638081991
#
#
# TRAIN: [0 1 2 3 5 6] TEST: [4]
# Predicted FEV1=  [3.18832445]
# True FEV1 =  [2.88]
# MSE =  0.09506396431509177
#
#
# TRAIN: [0 1 2 3 4 6] TEST: [5]
# Predicted FEV1=  [2.94787665]
# True FEV1 =  [2.96]
# MSE =  0.00014697555771159558
#
#
# TRAIN: [0 1 2 3 4 5] TEST: [6]
# Predicted FEV1=  [3.01673297]
# True FEV1 =  [3.65]
# MSE =  0.40102713335416507
#
#
# Running Regression on FVC
# TRAIN: [1 2 3 4 5 6] TEST: [0]
# Predicted FVC=  [3.80175323]
# True FVC =  [3.94]
# MSE =  0.019112169203735645
#
#
# TRAIN: [0 2 3 4 5 6] TEST: [1]
# Predicted FVC=  [3.7761905]
# True FVC =  [3.02]
# MSE =  0.5718240700077363
#
#
# TRAIN: [0 1 3 4 5 6] TEST: [2]
# Predicted FVC=  [3.54054574]
# True FVC =  [3.11]
# MSE =  0.18536963369805048
#
#
# TRAIN: [0 1 2 4 5 6] TEST: [3]
# Predicted FVC=  [3.57466517]
# True FVC =  [4.09]
# MSE =  0.2655699850998897
#
#
# TRAIN: [0 1 2 3 5 6] TEST: [4]
# Predicted FVC=  [3.51171661]
# True FVC =  [3.3]
# MSE =  0.04482392322820078
#
#
# TRAIN: [0 1 2 3 4 6] TEST: [5]
# Predicted FVC=  [3.60021279]
# True FVC =  [3.39]
# MSE =  0.04418941842976083
#
#
# TRAIN: [0 1 2 3 4 5] TEST: [6]
# Predicted FVC=  [3.26585278]
# True FVC =  [4.24]
# MSE =  0.9489628040047772
#
#
# Running Regression on PEF
# TRAIN: [1 2 3 4 5 6] TEST: [0]
# Predicted PEF=  [3.80175323]
# True PEF =  [3.94]
# MSE =  0.019112169203735645
#
#
# TRAIN: [0 2 3 4 5 6] TEST: [1]
# Predicted PEF=  [3.7761905]
# True PEF =  [3.02]
# MSE =  0.5718240700077363
#
#
# TRAIN: [0 1 3 4 5 6] TEST: [2]
# Predicted PEF=  [3.54054574]
# True PEF =  [3.11]
# MSE =  0.18536963369805048
#
#
# TRAIN: [0 1 2 4 5 6] TEST: [3]
# Predicted PEF=  [3.57466517]
# True PEF =  [4.09]
# MSE =  0.2655699850998897
#
#
# TRAIN: [0 1 2 3 5 6] TEST: [4]
# Predicted PEF=  [3.51171661]
# True PEF =  [3.3]
# MSE =  0.04482392322820078
#
#
# TRAIN: [0 1 2 3 4 6] TEST: [5]
# Predicted PEF=  [3.60021279]
# True PEF =  [3.39]
# MSE =  0.04418941842976083
#
#
# TRAIN: [0 1 2 3 4 5] TEST: [6]
# Predicted PEF=  [3.26585278]
# True PEF =  [4.24]
# MSE =  0.9489628040047772

# %%
list(cloth_pe)
# Out:
# [array([0.24181919]), array([0.16395103]), array([0.15282701])]

# %%
lt.latexify()
labels = ['FEV1', 'FVC', 'PEF']
#cloth_param = [0.48806677153707256, 0.4806901243588203, 4.0307028181078834]
#n95_param = [0.06917450064896391, 0.04246926740883565, 3.089989401165248]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(8,6))
rects1 = ax.bar(x - width/2, n95_pe, width, label='Cloth Mask')
rects2 = ax.bar(x + width/2, cloth_pe, width, label='N95 Mask')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('MAE')
ax.set_title('Mean Absoule Error For Differnet Type of Mask')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
lt.format_axes(ax)
# Out:
# C:\ProgramData\Anaconda3\lib\_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-0dcdf15bf105> in <module>()
#       8
#       9 fig, ax = plt.subplots(figsize=(8,6))
# ---> 10 rects1 = ax.bar(x - width/2, n95_pe, width, label='Cloth Mask')
#      11 rects2 = ax.bar(x + width/2, cloth_pe, width, label='N95 Mask')
#      12
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1429     def inner(ax, *args, data=None, **kwargs):
#    1430         if data is None:
# -> 1431             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1432
#    1433         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2484                 edgecolor=e,
#    2485                 linewidth=lw,
# -> 2486                 label='_nolegend_',
#    2487                 )
#    2488             r.update(kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     740         """
#     741
# --> 742         Patch.__init__(self, **kwargs)
#     743
#     744         self._x0 = xy[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      86         self.set_fill(fill)
#      87         self.set_linestyle(linestyle)
# ---> 88         self.set_linewidth(linewidth)
#      89         self.set_antialiased(antialiased)
#      90         self.set_hatch(hatch)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py in set_linewidth(self, w)
#     391                 w = mpl.rcParams['axes.linewidth']
#     392
# --> 393         self._linewidth = float(w)
#     394         # scale the dash pattern by the linewidth
#     395         offset, ls = self._us_dashes
#
# TypeError: only size-1 arrays can be converted to Python scalars
