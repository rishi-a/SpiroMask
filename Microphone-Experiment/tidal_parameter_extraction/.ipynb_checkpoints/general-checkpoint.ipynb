# %%
from utils import *
from extract_tidal import *
# Out:
# recorded_data/Anubhav_Tidal_Cloth_lap2.wav
# []
# []
# recorded_data/Anubhav_tidal_2.wav
# [1.79, 2.46, 2.25, 3.3200000000000003, 3.3200000000000003]
# [2.3899999999999997, 2.3999999999999995, 2.3200000000000003, 2.3000000000000007, 3.0, 3.559999999999995, 3.539999999999999, 2.989999999999995, 2.6499999999999986, 3.049999999999997, 2.180000000000007]
# recorded_data/Rishi_tidal_cloth_1_tmp.wav
# [2.6499999999999986, 2.700000000000003, 3.1899999999999977]
# [0.5599999999999996, 0.7899999999999991, 0.5700000000000003, 0.8499999999999943, 0.8100000000000023, 0.6499999999999986, 0.6500000000000057]
# recorded_data/Raviraj_Tidal_Cloth_1.wav
# [1.3500000000000085, 1.6899999999999977, 0.9000000000000057]
# ...

# %%
# convert_txt_to_audio_folder("extra_data/")

# %%
from scipy.io.wavfile import read
import matplotlib.pyplot as plt

# read audio samples
fs,sig = read("extra_data/Anubhav_Tidal_Cloth_lap3.wav")
sig = sig[90000:]
duration = len(sig)/fs
t = np.arange(0,duration,1/fs)
min_len = min(len(t),len(sig))
t = t[:min_len]
sig = sig[:min_len]
plt.title( "Anubhav (subject3) Tidal breathing")
plt.plot(t,sig)
# write("recorded_data/"+"Anubhav_Tidal_Cloth_lap2"+".wav",int(fs),sig)

# %%
from scipy.io.wavfile import read
import matplotlib.pyplot as plt

# read audio samples
fs,sig = read("recorded_data/extrated_params/Rishi_tidal_cloth_1_tmp.wav")
duration = len(sig)/fs
t = np.arange(0,duration,1/fs)
min_len = min(len(t),len(sig))
t = t[:min_len]
sig = sig[:min_len]
plt.title( "Rishiraj (subject1) ")
plt.plot(t[:20*fs],sig[:20*fs])
# write("recorded_data/extrated_params/Rishi_tidal_cloth_1_tmp.wav",int(fs),sig)

# %%
from scipy.io.wavfile import read
import matplotlib.pyplot as plt

# read audio samples
fs,sig = read("recorded_data/Rohit_tidal_2.wav")
duration = len(sig)/fs
t = np.arange(0,duration,1/fs)
min_len = min(len(t),len(sig))
t = t[:min_len]
sig = sig[:min_len]
plt.title("Rohit (subject 2)")
plt.plot(t[:20*fs],sig[:20*fs])
# write("recorded_data/extrated_params/Rishi_tidal_cloth_1_tmp.wav",int(fs),sig)

# %%
# from scipy.io.wavfile import read
# import matplotlib.pyplot as plt

# # read audio samples
# fs,sig = read("recorded_data/Anubhav_Tidal_Cloth_lap2.wav")
# duration = len(sig)/fs
# t = np.arange(0,duration,1/fs)
# min_len = min(len(t),len(sig))
# t = t[:min_len]
# sig = sig[:min_len]

# plt.plot(t[:20*fs],sig[:20*fs])
# # write("recorded_data/extrated_params/Rishi_tidal_cloth_1_tmp.wav",int(fs),sig)

# %%
import numpy as np
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
#LOSO Validation
loo = LeaveOneOut()
# loo.get_n_splits(X)

X = np.array([[2.2], [1.94],[2.84666666666667]])
y = np.array([1, 2.4, 1.9])
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted Ti= ", reg.predict(X_test))
    print("True Ti = ", y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("\n")
# Out:
# TRAIN: [1 2] TEST: [0]
# Predicted Ti=  [2.25661765]
# True Ti =  [1.]
# MSE =  1.5790879108996545
#
#
# TRAIN: [0 2] TEST: [1]
# Predicted Ti=  [0.63814433]
# True Ti =  [2.4]
# MSE =  3.104135402274413
#
#
# TRAIN: [0 1] TEST: [2]
# Predicted Ti=  [-2.48205128]
# True Ti =  [1.9]
# MSE =  19.2023734385274

# %%
import numpy as np
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
#LOSO Validation
loo = LeaveOneOut()
# loo.get_n_splits(X)
#Anubhav,Rohit,Rishi
X = np.array([[1.7], [0.7],[0.97]])
y = np.array([1.3, 2.7, 2.5])
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted Te= ", reg.predict(X_test))
    print("True Te = ", y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("\n")
# Out:
# TRAIN: [1 2] TEST: [0]
# Predicted Te=  [1.95925926]
# True Te =  [1.3]
# MSE =  0.43462277091906687
#
#
# TRAIN: [0 2] TEST: [1]
# Predicted Te=  [2.94383562]
# True Te =  [2.7]
# MSE =  0.059455807843872714
#
#
# TRAIN: [0 1] TEST: [2]
# Predicted Te=  [2.322]
# True Te =  [2.5]
# MSE =  0.031683999999999976

# %%
import numpy as np
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
#LOSO Validation
loo = LeaveOneOut()
# loo.get_n_splits(X)
#Anubhav,Rohit,Rishi
X = np.array([[15.146], [20.61],[16.86]])
y = np.array([22.22,11.76,13.64])
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted Rf= ", reg.predict(X_test))
    print("True Rf = ", y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("\n")
# Out:
# TRAIN: [1 2] TEST: [0]
# Predicted Rf=  [14.49928533]
# True Rf =  [22.22]
# MSE =  59.609434964081764
#
#
# TRAIN: [0 2] TEST: [1]
# Predicted Rf=  [-5.13187865]
# True Rf =  [11.76]
# MSE =  285.33556420609256
#
#
# TRAIN: [0 1] TEST: [2]
# Predicted Rf=  [18.93880673]
# True Rf =  [13.64]
# MSE =  28.077352814803795

# %%
import numpy as np
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
#LOSO Validation
loo = LeaveOneOut()
# loo.get_n_splits(X)
#Anubhav,Rohit,Rishi
X = np.array([[0.000220452759743], [0.000350877738038],[0.000556657631548]])
y = np.array([0.4,0.5,0.7])
for train_index, test_index in loo.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    reg = LinearRegression().fit(X_train, y_train)
    #print(X_train, X_test, y_train, y_test)
    #print("FVC with N95")
    #print("Coef = ",reg.coef_)
    #print("Intercept = ", reg.intercept_)
    print("Predicted VT= ", reg.predict(X_test))
    print("True VT = ", y_test)
    print("MSE = ", mean_squared_error(reg.predict(X_test), y_test))
    print("\n")
# Out:
# TRAIN: [1 2] TEST: [0]
# Predicted VT=  [0.37323837]
# True VT =  [0.4]
# MSE =  0.0007161850838261094
#
#
# TRAIN: [0 2] TEST: [1]
# Predicted VT=  [0.51637991]
# True VT =  [0.5]
# MSE =  0.0002683015262737448
#
#
# TRAIN: [0 1] TEST: [2]
# Predicted VT=  [0.65777644]
# True VT =  [0.7]
# MSE =  0.001782828638009283

# %%
def split_tidal_workflow(file):
    #this is the workflow:
    #10 s - break           0-10
    #30 s - tidal breathing 10-40
    #10 s - break           40-50
    #30 s - speaking        50-80
    #10 s - break           80-90
    #30 s - tidal with noise 90-end
    fs,sig = read(file)
    sig_tidal = sig[10*fs:40*fs]
    write(file+"_tidal_extracted.wav",fs,sig_tidal)
