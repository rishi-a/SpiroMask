# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Program Files (x86)\Helios\Data\3_Rishiraj\SpiroData\Data_10_Jul_2021-14_25_17.csv')

# %%
fig, ax = plt.subplots(1,1,figsize=(10,3))
ax.plot(np.linspace(0,60,len(df.index)), df['SVC_PRE:'])

# %%
-266.2828 = 0
-268.8934 = -2.89

# %%
-266+268.8934
# Out:
# 2.8933999999999855

# %%
df.loc[0]
# Out:
# SVC_PRE:   -266.2828
# Name: 0, dtype: float64

# %%
df['SVC_PRE:'] = df['SVC_PRE:'] + 266.2828

# %%
fig, ax = plt.subplots(1,1,figsize=(10,3))
ax.plot(np.linspace(0,60,len(df.index)), df['SVC_PRE:'])

# %% [markdown]
# ## FVC

# %%
df = pd.read_csv(r'C:\Program Files (x86)\Helios\Data\3_Rishiraj\SpiroData\Data_10_Jul_2021-14_52_53-FVC.csv')
df
# Out:
#      FVC_PRE:
# 0   -279.3359
# 1   -267.5881
# 2   -255.8403
# 3   -244.0926
# 4   -234.9554
# ..        ...
# 134 -357.6544
# 135 -357.6544
# 136 -358.9597
# 137 -358.9597
# 138 -358.9597
#
# [139 rows x 1 columns]

# %%
df['FVC_PRE:'] = ((df['FVC_PRE:'] - df.iloc[0].item())/10)+0.1813400000000005

df['FVC_PRE:'][0] = 0

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv(r'C:\Program Files (x86)\Helios\Data\4_Nipun Batra\SpiroData\Data_10_Jul_2021-15_02_58-FVC.csv')
df
# Out:
#      FVC_PRE:
# 0   -326.3270
# 1   -319.8004
# 2   -310.6633
# 3   -300.2208
# 4   -291.0836
# ..        ...
# 180 -356.3491
# 181 -356.3491
# 182 -357.6544
# 183 -357.6544
# 184 -358.9597
#
# [185 rows x 1 columns]

# %%
df['FVC_PRE:'] = ((df['FVC_PRE:'] - df.iloc[0].item())/10)+0.1813400000000005

df['FVC_PRE:'][0] = 0

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      FVC_PRE:
# 0     0.00000
# 1     0.83400
# 2     1.74771
# 3     2.79196
# 4     3.70568
# ..        ...
# 180  -2.82087
# 181  -2.82087
# 182  -2.95140
# 183  -2.95140
# 184  -3.08193
#
# [185 rows x 1 columns]
