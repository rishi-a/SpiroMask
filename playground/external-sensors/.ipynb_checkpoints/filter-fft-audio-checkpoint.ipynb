# %%
import matplotlib
import pandas as pd
import numpy as np
#import cbor2
import librosa
from scipy.signal import butter
from scipy.signal import lfilter
from scipy.signal import filtfilt
from scipy.signal import freqz
from scipy.signal import sosfreqz
import matplotlib.pyplot as plt
#import plotly.express as px
import IPython.display as ipd
import scipy.signal as signal

# %%
def compute_fft(s, sampling_rate, n = None, scale_amplitudes = True):
    '''Computes an FFT on signal s using numpy.fft.fft.
    
       Parameters:
        s (np.array): the signal
        sampling_rate (num): sampling rate
        n (integer): If n is smaller than the length of the input, the input is cropped. If n is 
            larger, the input is padded with zeros. If n is not given, the length of the input signal 
            is used (i.e., len(s))
        scale_amplitudes (boolean): If true, the spectrum amplitudes are scaled by 2/len(s)
    '''
    if n == None:
        n = len(s)
        
    fft_result = np.fft.fft(s, n)
    num_freq_bins = len(fft_result)
    fft_freqs = np.fft.fftfreq(num_freq_bins, d = 1 / sampling_rate)
    half_freq_bins = num_freq_bins // 2

    fft_freqs = fft_freqs[:half_freq_bins]
    fft_result = fft_result[:half_freq_bins]
    fft_amplitudes = np.abs(fft_result)
    
    if scale_amplitudes is True:
        fft_amplitudes = 2 * fft_amplitudes / (len(s))
    
    return (fft_freqs, fft_amplitudes);


def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='lowpass', output='ba', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    #y = lfilter(b, a, data)
    y = filtfilt(b, a, data)
    return y;


def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

def cbor2csv(filename):
    '''
    Function to convert cbro files to csv.
    Depends on: Numpy, Pandas and Cbor2 library
    Input: Filename with cbor
    Output: Stores the same name csv file
    '''
    with open(filename, 'rb') as fp:
        obj = cbor2.load(fp)  
        pd.DataFrame(data=np.array(obj['payload']['values']),columns=['X','Y','Z']).to_csv(filename.split('.')[0]+".csv", index=False)

# %% [markdown]
# ## LP filter using numerator/denominator method

# %%
1000/10000
# Out:
# 0.1

# %%
#load the audio data
fs=2000
y_o, fs = librosa.load("data/audio/multiTone.wav", sr=2000)
t_o = [s/fs for s in range(0,len(y_o))]

plt.plot(t_o,y_o)
plt.show()
F, A = compute_fft(y_o, fs, scale_amplitudes=False)
plt.plot(F[:50], A[:50])
plt.show()
plt.plot(F[:],A[:])
plt.show()

# %%
F[np.where(A == np.max(A[:50]))[0][0]]
# Out:
# 0.4

# %%
#load the speech audio data
#fs=2000
#y_o, fs = librosa.load("data/audio/speech.wav", sr=2000)
#t_o = [s/fs for s in range(0,len(y_o))]

#plt.plot(t_o,y_o)
#plt.show()
#F, A = compute_fft(y_o, fs, scale_amplitudes=False)
#plt.plot(F[:150], A[:150])
#plt.show()
#print("Max Frequency = {}".format(F[np.where(A == np.max(A))[0][0]]))
#np.max()))

# %%
# Plot the frequency response.
order = 5
cutoff = 1
b, a = butter_lowpass(cutoff, fs, order)
w, h = freqz(b, a, worN=512)
fig, ax = plt.subplots()
freqInResponse = 0.5*fs*w/np.pi #freq = (angularFreq)/2*pi [Normalsied angular freq->Angular freq->Freq]
ax.plot(freqInResponse, np.abs(h), 'b')
ax.plot(freqInResponse[np.argmax(np.abs(h))],max(np.abs(h)),'ro') 
ax.annotate(freqInResponse[np.argmax(np.abs(h))], (freqInResponse[np.argmax(np.abs(h))], max(np.abs(h))))
ax.axvline(cutoff, color='k')
#ax[0,1].set_xlim(0, 0.5*fs)
ax.set_title("Frequency Response of Low Pass Filter of Order {}".format(order))
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('Amplitude')
ax.set_xlim([0,1.5])
ax.grid()

# %%
cutoff = 1
fs = 2000

y_f = butter_lowpass_filter(y_o, cutoff, fs, order=5)
t_f = [s/fs for s in range(0,len(y_f))]

F, A = compute_fft(y_f, fs, scale_amplitudes=False)
#plt.plot(F[:150], A[:150])
#plt.show()
plt.plot(F[:100],A[:100])
plt.show()
print("Max Frequency = {}".format(F[np.where(A == np.max(A))[0][0]]))

fig, ax = plt.subplots(1,1,figsize=(8,4))

ax2 = ax.twinx()
ax.plot(t_o,y_o, 'b-', label='Unfiltered', alpha=0.5)
ax2.plot(t_f,y_f, 'g-', label='Filtered at 0.3 Hz')

#ax[0].plot(t_o,y_o)
#ax[1].plot(t_f,y_f)
ax.set_xlabel('Time')
ax.set_ylabel('Amplitude')
fig.legend()
# Out:
# Max Frequency = 0.4

# %% [markdown]
# ## LP filter using SOS method

# %%
from scipy.fft import fft, fftfreq

# %%
yf = fft(y_o)
xf = fftfreq(len(y_o), 1 / fs)

plt.plot(xf, np.abs(yf), lw=0.1)
plt.xlim((0, 1000))
# Out:
# (0.0, 1000.0)

# %%
# Out:
# 1

# %%
np.where(A == np.max(A))
# Out:
# (array([0], dtype=int64),)

# %%
order = 5
cutoff = 0.3
normal_cutoff = cutoff/(0.5*fs)
sos = signal.butter(order, cutoff, 'lp', fs=fs, output='sos')
filtered = signal.sosfilt(sos, y_o)
t_f = [s/fs for s in range(0,len(filtered))]

F, A = compute_fft(filtered, fs, scale_amplitudes=False)
#plt.plot(F[:150], A[:150])
#plt.show()
plt.plot(F[:100],A[:100])
plt.show()
print("Max Frequency = {}".format(F[np.where(A == np.max(A))[0][0]]))
print("Second largest Frequency = {}".format(F[np.where(A==np.partition(A, -3)[-3])[0][0]]))


fig, ax = plt.subplots(1,1,figsize=(8,4))
ax2 = ax.twinx()
ax.plot(t_o,y_o, 'b-', label='Unfiltered', alpha=0.5)
ax2.plot(t_f,filtered, 'g-', label='Filtered at 0.3 Hz', alpha=0.5)
# Out:
# Max Frequency = 0.0
# Second largest Frequency = 0.20129499781930416

# %%
F[:100]
# Out:
# array([0.        , 0.01677458, 0.03354917, 0.05032375, 0.06709833,
#        0.08387292, 0.1006475 , 0.11742208, 0.13419667, 0.15097125,
#        0.16774583, 0.18452041, 0.201295  , 0.21806958, 0.23484416,
#        0.25161875, 0.26839333, 0.28516791, 0.3019425 , 0.31871708,
#        0.33549166, 0.35226625, 0.36904083, 0.38581541, 0.40259   ,
#        0.41936458, 0.43613916, 0.45291375, 0.46968833, 0.48646291,
#        0.50323749, 0.52001208, 0.53678666, 0.55356124, 0.57033583,
#        0.58711041, 0.60388499, 0.62065958, 0.63743416, 0.65420874,
#        0.67098333, 0.68775791, 0.70453249, 0.72130708, 0.73808166,
#        0.75485624, 0.77163082, 0.78840541, 0.80517999, 0.82195457,
#        0.83872916, 0.85550374, 0.87227832, 0.88905291, 0.90582749,
#        0.92260207, 0.93937666, 0.95615124, 0.97292582, 0.98970041,
#        1.00647499, 1.02324957, 1.04002416, 1.05679874, 1.07357332,
#        1.0903479 , 1.10712249, 1.12389707, 1.14067165, 1.15744624,
#        1.17422082, 1.1909954 , 1.20776999, 1.22454457, 1.24131915,
#        1.25809374, 1.27486832, 1.2916429 , 1.30841749, 1.32519207,
#        1.34196665, 1.35874124, 1.37551582, 1.3922904 , 1.40906498,
#        1.42583957, 1.44261415, 1.45938873, 1.47616332, 1.4929379 ,
#        1.50971248, 1.52648707, 1.54326165, 1.56003623, 1.57681082,
#        1.5935854 , 1.61035998, 1.62713457, 1.64390915, 1.66068373])

# %%
w, h = sosfreqz(sos,worN=16000)
fig, ax = plt.subplots()
freqInResponse = 0.5*fs*w/np.pi
ax.plot(freqInResponse, np.abs(h), 'b')
ax.plot(freqInResponse[np.argmax(np.abs(h))],max(np.abs(h)),'ro') 
ax.annotate(freqInResponse[np.argmax(np.abs(h))], (freqInResponse[np.argmax(np.abs(h))]+0.15, max(np.abs(h))))
ax.axvline(cutoff, color='k')
#ax.set_xlim(0, 0.5*fs)
ax.set_xlim([0,cutoff+0.5])
ax.set_title("Frequency Response of Low Pass Filter of Order {}".format(order))
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('Amplitude')

ax.grid()

# %% [markdown]
# ## Using bandpass using numerator/denominator method

# %%
order = 2
low_cut = 0.2
high_cut = 0.3
fs = fs
b, a = butter_bandpass(low_cut, high_cut, fs, order)
w, h = freqz(b, a, worN=8000)
fig, ax = plt.subplots()
freqInResponse = 0.5*fs*w/np.pi
ax.plot(freqInResponse, np.abs(h), 'b')
ax.plot(freqInResponse[np.argmax(np.abs(h))],max(np.abs(h)),'ro') 
ax.annotate(freqInResponse[np.argmax(np.abs(h))], (freqInResponse[np.argmax(np.abs(h))]+0.15, max(np.abs(h))))
ax.axvline(cutoff, color='k')
#ax[0,1].set_xlim(0, 0.5*fs)
ax.set_title("Frequency Response of Low Pass Filter of Order {}".format(order))
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('Amplitude')
ax.set_xlim([0,0.8])
ax.grid()

#y_f_bp = butter_bandpass_filter(y_o, 0.2, 0.3, fs, order=5):

# %%
y_f = butter_bandpass_filter(y_o, low_cut, high_cut, fs, order=order)
t_f = [s/fs for s in range(0,len(y_f))]

fig, ax = plt.subplots(1,1,figsize=(8,4))

ax2 = ax.twinx()
ax.plot(t_o,y_o, 'b-', label='Unfiltered', alpha=0.5)
ax2.plot(t_f,y_f, 'g-', label='Filtered at 0.3 Hz')

#ax[0].plot(t_o,y_o)
#ax[1].plot(t_f,y_f)
ax.set_xlabel('Time')
ax.set_ylabel('Amplitude')
fig.legend()
