# %% [markdown]
# This script is meant to find the hilbert transform envelope of the audio signal. It creates a csv file with true and estiamted param of PEF, FEV1 and FVC. The csv is further used in the ML pipeline

# %%
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from scipy.io import wavfile # package to read WAV file
import pandas as pd
sns.set_style("white")
sns.set_style("ticks")
import warnings
warnings.filterwarnings("ignore")
import latexify as lt
import librosa
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import json
import matplotlib.pyplot as plt # matplot lib is the premiere plotting lib for Python: https://matplotlib.org/
import numpy as np # numpy is the premiere signal handling library for Python: http://www.numpy.org/
import scipy as sp # for signal processing
from scipy import signal
from scipy.io import wavfile

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import Audio

#for filter
from scipy.signal import butter
from scipy.signal import lfilter
from scipy.signal import freqz;

# %%
def butter_highpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='highpass', analog=False)
    return b, a

def butter_highpass_filter(data, cutoff, fs, order=5):
    b, a = butter_highpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y;

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
#execute one time only
data = pd.DataFrame(
    {'Name': [],
     'Filename':[],
     'rPEF': [],
     'rFEV1': [],
     'rFVC': [],
     'rRatio':[],
     'gPEF': [],
     'gFEV1': [],
     'gFVC': [],
     'gRatio':[]
    })
data.to_csv('data_FVC_Cloth.csv')

# %%
import os
#read the ground truth file
#open the file where the measured values present
f = open('groundTruth.json')
measured = json.load(f)

#select path where audio data is stored
mypath="SpiroMask-July2021/SmartMaskData/FVC/Cloth/"
(_, _, filenames) = next(os.walk(mypath))
names = [file.split('.')[0] for file in filenames]
#read the csv where final computed data is stored
df = pd.read_csv('data_FVC_Cloth.csv')


#read the ground truth file
for i in range(1,len(measured['Name'])+1):
    fig,ax = plt.subplots(1,1,figsize=(2,2))
    #if the dataframe already contains the name then dont do anything
    if df['Name'].str.contains(measured['Name'][str(i)]).sum() > 0:
        print("Entry for Name {} already exists, moving to next file".format(measured['Name'][str(i)]))
        continue;
    else:
        try:
            file = filenames[names.index(measured['Name'][str(i)])]
            print("File {} found".format(file))
            #store ground truth data
            gPEF = measured['PEF'][str(i)]
            gFEV1 = measured['FEV1'][str(i)]
            gFVC = measured['FVC'][str(i)]
            gRatio = gFEV1/gFVC*100

            print('Processing Hilbert Transformation . . .')
            #calculate predictions base on HT
            x, fs = librosa.load(mypath+file)
            t = np.arange(0,len(x))/fs
            cutoff_low = 3000 # desired cutoff frequency of the filter, Hz
            cutoff_high = 5000
            order = 10

            #x_filt = butter_highpass_filter(x, cutoff, fs, order)
            x_filt = butter_bandpass_filter(x,cutoff_low,cutoff_high,fs,order)
            x_filt_hilbert = signal.hilbert(x_filt)
            envelope_hat = np.abs(x_filt_hilbert)
            #filter the Hilbert envelope
            nyq_rate = fs /0.5
            width = 1.0/nyq_rate # 5 Hz filter transition width.
            ripple_db = 10.0 # stop band attenuation
            fL_hz = 10
            N, beta = signal.kaiserord(ripple_db, width)
            taps = signal.firwin(N, fL_hz/nyq_rate, window=('kaiser', beta))
            envelope_hat_filt = signal.filtfilt(taps, 1,envelope_hat)
            t = np.arange(0,len(envelope_hat_filt))/fs

            #at this point we have the 
            #scale the envelope is estimate of flow rate. We will scale this to match actual flow range
            envelope_hat_filt = np.interp(envelope_hat_filt, (envelope_hat_filt.min(), 1), (0, 8))
            rPEF = round(envelope_hat_filt.max(),2)

            estdVolume = np.cumsum(envelope_hat_filt)
            estdVolume = np.interp(estdVolume, (0, np.cumsum([1]*len(t)).max()), (0, 8))
            #FEV1 Estimate
            rFEV1 = round(estdVolume[np.where(t==1)[0][0]],2)
            #FVC Estimate
            rFVC = round(estdVolume[-1],2)

            rRatio = (rFEV1/rFVC)*100


            row = {'Name': measured['Name'][str(i)], 'Filename':file, 'rPEF': rPEF, 'rFEV1': rFEV1, 'rFVC':rFVC, 'rRatio': rRatio, 'gPEF': gPEF, 'gFEV1': gFEV1, 'gFVC':gFVC, 'gRatio': gRatio}
            df = df.append(row, ignore_index = True)
            print('Completed Writing data to dataframe')
            #estdVolume = estdVolume/np.max(estdVolume)
            ax.plot(estdVolume, envelope_hat_filt)
            ax.set_xlabel('Estimated Volume')
            ax.set_ylabel('Estimated Flow')
        except:
            print("Error with = {}".format(measured['Name'][str(i)]))
            continue;
# Out:
# File Maithili01.FVC_C.2b677eno.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Rahul01.FVC_C.2b8ks79f.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File ShikhaD01.FVC_C.2b6c0d7k.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Vignesh01.FVC_C.2bb95nom.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Yash01.FVC_C.2b8n937i.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Sandra01.FVC_C.2bdaignt.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Hatim01.FVC_C.2be1a9u6.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Maithili02.FVC_C.2b676jbf.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# Error with = Rahul02
# File Kaushal01.FVC_C.06.LCL.2bldi9ts.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Kaushal02.FVC_C.06.LCL.2bldi9ts.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Alok01.FVC_C.2blkl0aa.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Monika01.FVC_C.2blm3kre.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# Error with = Monika02
# File Alok02.FVC_C.2blkl0aa.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Rik01.FVC_C.2bql7p8d.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Rik02.FVC_C.2bql8pcq.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Yashi01.FVC_C.2c030o23.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Yashi02.FVC_C.2c031hlj.wav found
# Error with = Yashi02
# File ShikhaD02.FVC_C.2b6c166t.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Hatim02.FVC_C.2be19f00.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Utpal01.FVC_C.2aa5mc0u.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Vinod01.FVC_C.2c1u1de2.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Xhitij01.FVC_C.2c2a0igf.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# Error with = Xhitij02
# File Suvigya01.FVC_C.2bb5jvic.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Suvigya02.FVC_C.2bb5jvic.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Vignesh02.FVC_C.2bb96h9f.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe
# File Yash02.FVC_C.2b8n9thr.wav found
# Processing Hilbert Transformation . . .
# Completed Writing data to dataframe

# %%
df.to_csv('data_FVC_Cloth.csv')

# %% [markdown]
# ### Save the HT envelope information in a pickle file

# %%
import os
#read the ground truth file
#open the file where the measured values present
f = open('groundTruth.json')
measured = json.load(f)

#select path where audio data is stored
mypath="SpiroMask-July2021/SmartMaskData/FVC/Cloth/"
(_, _, filenames) = next(os.walk(mypath))
names = [file.split('.')[0] for file in filenames]


di = {}

for file in filenames:
    x, fs = librosa.load(mypath+file)
    t = np.arange(0,len(x))/fs
    cutoff_low = 3000 # desired cutoff frequency of the filter, Hz
    cutoff_high = 5000
    order = 10

    #x_filt = butter_highpass_filter(x, cutoff, fs, order)
    x_filt = butter_bandpass_filter(x,cutoff_low,cutoff_high,fs,order)
    x_filt_hilbert = signal.hilbert(x_filt)
    envelope_hat = np.abs(x_filt_hilbert)
    #filter the Hilbert envelope
    nyq_rate = fs /0.5
    width = 1.0/nyq_rate # 5 Hz filter transition width.
    ripple_db = 10.0 # stop band attenuation
    fL_hz = 10
    N, beta = signal.kaiserord(ripple_db, width)
    taps = signal.firwin(N, fL_hz/nyq_rate, window=('kaiser', beta))
    envelope_hat_filt = signal.filtfilt(taps, 1,envelope_hat)
    t = np.arange(0,len(envelope_hat_filt))/fs

    #at this point we have the 
    #scale the envelope is estimate of flow rate. We will scale this to match actual flow range
    envelope_hat_filt = np.interp(envelope_hat_filt, (envelope_hat_filt.min(), 1), (0, 8))
    
    di[file] = envelope_hat_filt

# %%
import tsfel
import pickle
def getTSfeatures(data):
    cfg = tsfel.get_features_by_domain()
    stat_features = np.array(tsfel.time_series_features_extractor(cfg, data))[0]
    return stat_features

# %%
envelopeTSf = {}
for key in di:
    envelopeTSf[key] = getTSfeatures(di[key])
    print("Done for = {}".format(key))
# Out:
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Alok01.FVC_C.2blkl0aa.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Alok02.FVC_C.2blkl0aa.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Hatim01.FVC_C.2be1a9u6.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Hatim02.FVC_C.2be19f00.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Kaushal01.FVC_C.06.LCL.2bldi9ts.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Kaushal02.FVC_C.06.LCL.2bldi9ts.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Maithili01.FVC_C.2b677eno.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Maithili02.FVC_C.2b676jbf.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Monika01.FVC_C.2blm3kre.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Rahul01.FVC_C.2b8ks79f.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='60'
#                   max='60',
#                   style='width: 25%',
#               >
#                   60
#               </progress>
# Done for = Rik01.FVC_C.2bql7p8d.wav
# *** Feature extraction started ***
# 60
#               <p>
#                   Progress: 6% Complete
#               <p/>
#               <progress
#                   value='4'
#                   max='60',
#                   style='width: 25%',
#               >
#                   4
#               </progress>
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-26-e42635a1d846> in <module>
#       1 envelopeTSf = {}
#       2 for key in di:
# ----> 3     envelopeTSf[key] = getTSfeatures(di[key])
#       4     print("Done for = {}".format(key))
#
# <ipython-input-24-983c85a04c36> in getTSfeatures(data)
#       3 def getTSfeatures(data):
#       4     cfg = tsfel.get_features_by_domain()
# ----> 5     stat_features = np.array(tsfel.time_series_features_extractor(cfg, data))[0]
#       6     return stat_features
#
# ~\AppData\Roaming\Python\Python36\site-packages\tsfel\feature_extraction\calc_features.py in time_series_features_extractor(dict_features, signal_windows, fs, verbose, **kwargs)
#     273             feat_val = calc_window_features(dict_features, signal_windows, fs, verbose=verbose, single_window=True,
#     274                                             features_path=features_path,
# --> 275                                             header_names=names)
#     276             feat_val.reset_index(drop=True)
#     277             return feat_val
#
# ~\AppData\Roaming\Python\Python36\site-packages\tsfel\feature_extraction\calc_features.py in calc_window_features(dict_features, signal_window, fs, verbose, single_window, **kwargs)
#     460
#     461                     execf += ')'
# --> 462                     eval_result = eval(execf, locals())
#     463
#     464                     # Function returns more than one element
#
# <string> in <module>
#
# ~\AppData\Roaming\Python\Python36\site-packages\tsfel\feature_extraction\features.py in lpcc(signal, n_coeff)
#    1518     """
#    1519     # 12-20 cepstral coefficients are sufficient for speech recognition
# -> 1520     lpc_coeffs = lpc(signal, n_coeff)
#    1521
#    1522     if np.sum(lpc_coeffs) == 0:
#
# ~\AppData\Roaming\Python\Python36\site-packages\tsfel\feature_extraction\features_utils.py in lpc(signal, n_coeff)
#     226         return tuple(np.zeros(n_coeff+1))
#     227
# --> 228     lpc_coeffs = np.dot(np.linalg.inv(smatrix), -r[1:])
#     229
#     230     return tuple(np.concatenate(([1.], lpc_coeffs)))
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     544     signature = 'D->D' if isComplexType(t) else 'd->d'
#     545     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 546     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     547     return wrap(ainv.astype(result_t, copy=False))
#     548
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
with open('ts-fel-cloth-Envelope.pickle', 'wb') as handle:
    pickle.dump(envelopeTSf, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
for key in envelopeTSf:
    print(envelopeTSf[key].shape)
# Out:
# (390,)
# (390,)
# (390,)
# (390,)
# (390,)
# (390,)
# (390,)
# (390,)
# (390,)
# (390,)
# (390,)
